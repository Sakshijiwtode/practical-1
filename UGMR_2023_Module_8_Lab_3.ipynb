# %% [markdown]
# <a href="https://colab.research.google.com/github/Sakshijiwtode/practical-1/blob/main/UGMR_2023_Module_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-31 15:24:05--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   154MB/s    in 0.4s
#
# 2024-03-31 15:24:05 (154 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 1095   1708.02979v1  It is a well-known fact that adding noise to t...    cs
# 11359  1511.01942v1  We present and analyze several strategies for ...    cs
# 13866  1512.03466v1  NM-landscapes have been recently introduced as...    cs
# 6298   1611.01144v5  Categorical variables are a natural choice for...  stat
# 8852   1602.01635v2  Categorical compositional distributional seman...    cs
# ...             ...                                                ...   ...
# 37111  1607.08038v1  In this paper we outline the approach of solvi...    cs
# 7218   1711.02478v2  This paper introduces the combinatorial Boolea...  stat
# 6170   1608.07892v3  Recurrent neural network (RNN)'s architecture ...  stat
# 6688   1705.04977v4  Interpreting neural networks is a crucial and ...  stat
# 2376    1210.4184v1  In this work, we propose the kernel Pitman-Yor...    cs
#
#                                                    title  year  \
# 1095   Tikhonov Regularization for Long Short-Term Me...  2017
# 11359          Stop Wasting My Gradients: Practical SVRG  2015
# 13866  Computing factorized approximations of Pareto-...  2015
# 6298   Categorical Reparameterization with Gumbel-Sof...  2016
# 8852   A Generalised Quantifier Theory of Natural Lan...  2016
# ...                                                  ...   ...
# 37111  Behavior and path planning for the coalition o...  2016
# 7218   Grafting for Combinatorial Boolean Model using...  2017
# 6170   Optimizing Recurrent Neural Networks Architect...  2016
# 6688   Detecting Statistical Interactions from Neural...  2017
# 2376                       The Kernel Pitman-Yor Process  2012
#
#                                                 keywords
# 1095   [performance, technique, recurrent, connection...
# 11359  [strategies, improving, performance, stochasti...
# 13866  [landscapes, introduced, interaction, interact...
# 6298   [categorical, variables, representing, structu...
# 8852   [categorical, compositional, distributional, s...
# ...                                                  ...
# 37111  [navigation, coalition, environment, originall...
# 7218   [introduces, combinatorial, combinations, conj...
# 6170   [recurrent, architecture, influencing, perform...
# 6688   [interpreting, challenging, framework, detecti...
# 2376   [nonparametric, clustering, interdependencies,...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 1095     [performance, technique, recurrent, connection...
# 11359    [strategies, improving, performance, stochasti...
# 13866    [landscapes, introduced, interaction, interact...
# 6298     [categorical, variables, representing, structu...
# 8852     [categorical, compositional, distributional, s...
#                                ...
# 7815     [distributed, attracted, attention, especially...
# 22826    [borrowing, knowledge, different, sufficient, ...
# 9581     [functional, resonance, remarkable, achievemen...
# 11321    [recommender, preferences, behaviors, typicall...
# 30318    [preliminary, determine, linguistic, depressio...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8689 words.
# Out of those 4573 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="5f156f79-d441-4ae9-82a2-b07c490de99a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5f156f79-d441-4ae9-82a2-b07c490de99a")) {                    Plotly.newPlot(                        "5f156f79-d441-4ae9-82a2-b07c490de99a",                        [{"x":["performance","computation","feedforward","regularization","complicated","considers","parameter","derivation","lipschitz","interaction","technique","developed","functions","naturally","perturbation","continuous","different","connections","architectures","recurrent","independent","dependences","parameters","simplicity","regularizer","difficulties","regularizers","straightforward","stability","regularize","generalization","iterations","justified","selection","strategies","practical","computations","improving","stochastic","regularized","gradients","calculations","convergence","preserved","alternate","decreasing","iteration","approximations","properties","extensively","algorithms","probabilistic","implement","introduced","investigate","theoretical","objective","factorized","distributions","boltzmann","distribution","evolutionary","landscapes","factorizations","computing","combination","interactions","landscape","essential","estimator","supervised","efficient","reparameterization","structured","differentiable","backpropagate","prediction","structure","categorical","inability","representing","outperforms","generative","estimators","variables","unsupervised","classification","underlying","formalises","instantiate","quantifier","statistical","relational","equivalence","quantifiers","compositional","dimensional","quantified","formalisation","theoretic","compositionally","distributional","instantiation","sentences","generalised","relations","semantics","iterative","resolutions","counterparts","resolution","detection","algorithm","precision","specifically","respectively","therefore","increases","candidates","demonstrate","instances","effectiveness","evaluation","proposals","deconvolution","furthermore","regression","recursive","operation","generating","incorporates","designing","leverages","analyzers","expensive","benefiting","linguistic","effective","important","significant","knowledge","automated","unsatisfactory","extracting","information","framework","syntactic","segmentation","construction","extraction","improvements","available","languages","fundamental","successfully","requiring","developers","researchers","controlled","communication","representations","terminology","differences","traditionally","contribute","notations","scattered","especially","comprehensive","describing","understanding","presented","interested","translation","decisions","conceptual","propositional","intuitive","ambiguity","automatically","hierarchical","challenging","convolutional","significantly","magnitude","holistically","supervision","orthogonal","validation","reliability","conjunction","applicability","positives","guidelines","difficult","strengths","highlight","controlling","competing","demonstrated"],"y":[864,139,21,89,32,42,129,8,8,94,260,190,232,52,17,119,757,56,104,134,125,1,263,32,24,31,8,32,38,10,105,39,7,148,97,162,38,105,142,37,31,13,119,17,9,16,37,32,200,46,617,165,61,127,147,156,154,6,125,20,211,66,8,4,154,125,88,13,64,28,176,415,5,111,22,1,248,322,15,4,76,254,137,18,122,148,484,104,1,8,2,148,26,26,4,25,203,19,4,46,1,15,12,56,7,81,90,60,10,16,104,343,862,88,210,94,151,52,25,564,103,222,262,27,13,158,115,28,50,103,36,46,36,1,66,4,70,235,327,253,311,87,10,53,645,540,47,212,64,133,101,319,88,90,91,51,8,70,30,66,240,7,56,29,37,2,5,118,54,31,162,201,29,99,53,18,26,38,17,166,111,292,365,270,63,4,45,19,43,37,17,38,9,18,127,15,38,11,19,103],"type":"bar"},{"x":["performance","computation","feedf ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4573,), (4573, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.78

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>No</span> <span style=''>more</span> <span style=''>meta</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameter</span> <span style=''>tuning</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>unsupervised</span> <span style=''>sparse</span> <span style=''>feature</span> <span style=''>learning</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>meta</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameter</span> <span style=''>free</span> <span style=''>off</span> <span style=''>the</span> <span style=''>shelf</span> <span style=''>simple</span> <span style=''>and</span> <span style=''>fast</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>unsupervised</span> <span style=''>feature</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>which</span> <span style=''>exploits</span> <span style=''>a</span> <span style=''>new</span> <span style=''>way</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimizing</span> <span style=''>for</span> <span style=''>sparsity</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Experiments</span> <span style=''>on</span> <span style=''>STL</span> <span style=''>10</span> <span style=''>show</span> <span style=''>that</span> <span style=''>the</span> <span style=''>method</span> <span style=''>presents</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>and</span> <span style=''>provides</span> <span style='background-color:rgba(0, 255, 0, 0.48031496062992124);'>discriminative</span> <span style=''>features</span> <span style=''>that</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generalize</span> <span style=''>well</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Machine</span> <span style=''>Learning</span> <span style=''>for</span> <span style=''>Partial</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Identification</span> <span style=''>Example</span> <span style=''>of</span> <span style=''>Bracketed</span> <span style=''>Data</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Partially</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>identified</span> <span style=''>models</span> <span style=''>occur</span> <span style=''>commonly</span> <span style=''>in</span> <span style=''>economic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <span style=''>A</span> <span style=''>common</span> <span style=''>problem</span> <span style=''>in</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>literature</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>problem</span> <span style=''>with</span> <span style=''>bracketed</span> <span style=''>(interval</span> <span style=''>censored)</span> <span style=''>outcome</span> <span style=''>variable</span> <span style=''>Y</span> <span style=''>which</span> <span style=''>creates</span> <span style=''>a</span> <span style=''>set</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>identified</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameter</span> <span style=''>of</span> <span style=''>interest</span> <span style=''>The</span> <span style=''>recent</span> <span style=''>studies</span> <span style=''>have</span> <span style=''>only</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>considered</span> <span style=''>finite</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>linear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>in</span> <span style=''>such</span> <span style=''>context</span> <span style=''>To</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>incorporate</span> <span style=''>more</span> <span style=''>complex</span> <span style=''>controls</span> <span style=''>into</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>we</span> <span style=''>consider</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>partially</span> <span style=''>linear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>projection</span> <span style=''>of</span> <span style=''>Y</span> <span style=''>on</span> <span style=''>the</span> <span style=''>set</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>that</span> <span style=''>are</span> <span style=''>linear</span> <span style=''>in</span> <span style=''>treatmentpolicy</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonlinear</span> <span style=''>in</span> <span style=''>the</span> <span style=''>controls</span> <span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>characterize</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>identified</span> <span style=''>set</span> <span style=''>for</span> <span style=''>the</span> <span style=''>linear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>component</span> <span style=''>of</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>projection</span> <span style=''>and</span> <span style=''>propose</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimator</span> <span style=''>of</span> <span style=''>its</span> <span style=''>support</span> <span style=''>function</span> <span style=''>Our</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimator</span> <sp ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>On</span> <span style=''>the</span> <span style=''>Testable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Implications</span> <span style=''>of</span> <span style=''>Causal</span> <span style=''>Models</span> <span style=''>with</span> <span style=''>Hidden</span> <span style='background-color:rgba(255, 0, 0, 0.3822784810126582);'>Variables</span> <br/><br/><span style=''>The</span> <span style=''>validity</span> <span style=''>OF</span> <span style=''>a</span> <span style=''>causal</span> <span style=''>model</span> <span style=''>can</span> <span style=''>be</span> <span style=''>tested</span> <span style=''>ONLY</span> <span style=''>IF</span> <span style=''>the</span> <span style=''>model</span> <span style=''>imposes</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constraints</span> <span style=''>ON</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style=''>that</span> <span style=''>governs</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generated</span> <span style=''>data</span> <span style=''>IN</span> <span style=''>the</span> <span style=''>presence</span> <span style=''>OF</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>unmeasured</span> <span style='background-color:rgba(255, 0, 0, 0.3822784810126582);'>variables</span> <span style=''>causal</span> <span style=''>models</span> <span style=''>may</span> <span style=''>impose</span> <span style=''>two</span> <span style=''>types</span> <span style=''>OF</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constraints</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditional</span> <span style='background-color:rgba(255, 0, 0, 0.4285714285714285);'>independencies</span> <span style=''>AS</span> <span style=''>READ</span> <span style=''>through</span> <span style=''>the</span> <span style=''>d</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>separation</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>criterion</span> <span style=''>AND</span> <span style='background-color:rgba(255, 0, 0, 0.34482758620689646);'>functional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constraints</span> <span style=''>FOR</span> <span style=''>which</span> <span style=''>no</span> <span style=''>general</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>criterion</span> <span style=''>IS</span> <span style=''>availableThis</span> <span style=''>paper</span> <span style=''>offers</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.35593220338983056);'>systematic</span> <span style=''>way</span> <span style=''>OF</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>identifying</span> <span style='background-color:rgba(255, 0, 0, 0.34482758620689646);'>functional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constraints</span> <span style=''>AND</span> <span style=''>thus</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>facilitates</span> <span style=''>the</span> <span style=''>task</span> <span style=''>OF</span> <span style=''>testing</span> <span style=''>causal</span> <span style=''>models</span> <span style=''>AS</span> <span style=''>well</span> <span style=''>AS</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>inferring</span> <span style=''>such</span> <span style=''>models</span> <span style=''>FROM</span> <span style=''>data</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Dictionaries</span> <span style=''>with</span> <span style=''>Bounded</span> <span style=''>Self</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Coherence</span> <br/><br/><span style=''>Sparse</span> <span style=''>coding</span> <span style=''>in</span> <span style=''>learned</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dictionaries</span> <span style=''>has</span> <span style=''>been</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>established</span> <span style=''>as</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>successful</span> <span style=''>approach</span> <span style=''>for</span> <span style=''>signal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>denoising</span> <span style=''>source</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>separation</span> <span style=''>and</span> <span style=''>solving</span> <span style=''>inverse</span> <span style=''>problems</span> <span style=''>in</span> <span style=''>general</span> <span style=''>A</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dictionary</span> <span style=''>learning</span> <span style=''>method</span> <span style=''>adapts</span> <span style=''>an</span> <span style=''>initial</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dictionary</span> <span style=''>to</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>particular</span> <span style=''>signal</span> <span style=''>class</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>iteratively</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computing</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>factorization</span> <span style=''>of</span> <span style=''>a</span> <span style=''>training</span> <span style=''>data</span> <span style=''>matrix</span> <span style=''>into</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dictionary</span> <span style=''>and</span> <span style=''>a</span> <span style=''>sparse</span> <span style=''>coding</span> <span style=''>matrix</span> <span style=''>The</span> <span style=''>learned</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dictionary</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>characterized</span> <span style=''>by</span> <span style=''>two</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>properties</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>coherence</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dictionary</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observations</span> <span style=''>of</span> <span style=''>the</span> <span style=''>signal</span> <span style=''>class</span> <span style=''>and</span> <span style=''>the</span> <span style=''>self</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>coherence</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dictionary</span> <span style=''>atoms</span> <span style=''>A</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>coherence</span> <span style=''>to</span> <span style=''>the</span> <span style=''>signal</span> <span style=''>class</span> <span style=''>enables</span> <span style=''>the</span> <span style=''>sparse</span> <span style=''>coding</span> <span style=''>of</span> <span style=''>signal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observations</span> <span style=''>with</span> <span style=''>a</span> <span style=''>small</span> <span style='background-color:rgb ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	challenging (0.10391459074733096)
# 	processing (0.10320284697508897)
# 	architecture (0.08469750889679716)
# 	representation (0.13167259786476868)
# 	experimental (0.1391459074733096)
# 	segmentation (0.07544483985765124)
# 	detection (0.12206405693950179)
# 	convolutional (0.1298932384341637)
# 	different (0.2693950177935943)
# 	recognition (0.1320284697508897)
#
# Some Statistics words are:
# 	stochastic (0.14020100502512564)
# 	statistical (0.14321608040201006)
# 	algorithm (0.39798994974874374)
# 	variables (0.1371859296482412)
# 	estimation (0.1728643216080402)
# 	theoretical (0.157286432160804)
# 	distribution (0.1829145728643216)
# 	dimensional (0.18643216080402011)
# 	inference (0.20050251256281407)
# 	regression (0.18040201005025125)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a2683245-67c5-439f-bbba-7874e4c1a2d1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a2683245-67c5-439f-bbba-7874e4c1a2d1")) {                    Plotly.newPlot(                        "a2683245-67c5-439f-bbba-7874e4c1a2d1",                        [{"x":["performance","computation","feedforward","regularization","complicated","considers","parameter","derivation","lipschitz","interaction","technique","developed","functions","naturally","perturbation","continuous","different","connections","architectures","recurrent","independent","dependences","parameters","simplicity","regularizer","difficulties","regularizers","straightforward","stability","regularize","generalization","iterations","justified","selection","strategies","practical","computations","improving","stochastic","regularized","gradients","calculations","convergence","preserved","alternate","decreasing","iteration","approximations","properties","extensively","algorithms","probabilistic","implement","introduced","investigate","theoretical","objective","factorized","distributions","boltzmann","distribution","evolutionary","landscapes","factorizations","computing","combination","interactions","landscape","essential","estimator","supervised","efficient","reparameterization","structured","differentiable","backpropagate","prediction","structure","categorical","inability","representing","outperforms","generative","estimators","variables","unsupervised","classification","underlying","formalises","instantiate","quantifier","statistical","relational","equivalence","quantifiers","compositional","dimensional","quantified","formalisation","theoretic","compositionally","distributional","instantiation","sentences","generalised","relations","semantics","iterative","resolutions","counterparts","resolution","detection","algorithm","precision","specifically","respectively","therefore","increases","candidates","demonstrate","instances","effectiveness","evaluation","proposals","deconvolution","furthermore","regression","recursive","operation","generating","incorporates","designing","leverages","analyzers","expensive","benefiting","linguistic","effective","important","significant","knowledge","automated","unsatisfactory","extracting","information","framework","syntactic","segmentation","construction","extraction","improvements","available","languages","fundamental","successfully","requiring","developers","researchers","controlled","communication","representations","terminology","differences","traditionally","contribute","notations","scattered","especially","comprehensive","describing","understanding","presented","interested","translation","decisions","conceptual","propositional","intuitive","ambiguity","automatically","hierarchical","challenging","convolutional","significantly","magnitude","holistically","supervision","orthogonal","validation","reliability","conjunction","applicability","positives","guidelines","difficult","strengths","highlight","controlling","competing","demonstrated","weaknesses","notoriously","treatment","treatments","regardless","applications","potential","introduce","expanding","collectively","unfairness","experiment","classifiers","inspiration","literature","synthetic","tractable","detecting","economics","stringent","preference","developing","implementation","artificial","accuracies","investigated","generation","categorized","abstraction","benchmarked","advantage","consumption","techniques","environments","explicitly","bottleneck","diagonalization","synchronization","optimization","approximate","calculation","subsampled","thoroughly","partitions","situations","direction","experiments","terminate","distributed","particular","incorporated","secondary","recognit ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	subsampled
# 	terminate
# 	confounders
# 	circumvents
# 	inspecting
# 	stragglers
# 	confounder
# 	identifiable
# 	tightening
# 	newtonian
# 	beginnings
# 	statistician
# 	cytometry
# 	recombines
# 	activating
# 	bernstein
# 	operationally
# 	archetypal
# 	nonlinearly
# 	correntropy
# Some words which never appear in Statistics papers:
# 	quantifier
# 	quantifiers
# 	formalisation
# 	semantics
# 	benefiting
# 	terminology
# 	propositional
# 	benchmarked
# 	transduction
# 	preprocessed
# 	admitting
# 	semiautomatic
# 	metastases
# 	ultrasound
# 	pancreatic
# 	suffering
# 	displacement
# 	alzheimer
# 	electroencephalograms
# 	transducer

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.06063110213326e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7308333333333333
